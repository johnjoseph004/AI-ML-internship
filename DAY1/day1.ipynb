# %% [markdown]
# <a href="https://colab.research.google.com/github/johnjoseph004/AI-ML-internship/blob/main/day1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df =pd.read_csv("/content/Zudio_sales_data.csv")
df.head(10)
# Out:
#    Store Country          State       City Category Clothing Type  \
# 0  Zudio   India      Karnataka      Jalna    Women       Dresses
# 1  Zudio   India        Gujarat      Patna     Kids        Skirts
# 2  Zudio   India  Uttar Pradesh    Kolkata      Men       Hoodies
# 3  Zudio   India    West Bengal    Kolkata    Women       Dresses
# 4  Zudio   India    West Bengal   Guwahati      Men       Dresses
# 5  Zudio   India    West Bengal     Nashik     Kids       Jackets
# 6  Zudio   India    Maharashtra    Lucknow     Kids       Jackets
# 7  Zudio   India    West Bengal  Hyderabad    Women          Tops
# 8  Zudio   India      Karnataka  Ahmedabad      Men         Shoes
# 9  Zudio   India      Karnataka  Hyderabad     Kids         Jeans
#
#    Store Number  Postal Code Store Type Store Open Date  ...  \
# 0            30       411084      Owned      2022-06-04  ...
# 1            48       404562      Owned      2020-12-19  ...
# ...

# %%
df.tail(10)
# Out:
#       Store Country          State        City Category Clothing Type  \
# 7889  Zudio   India  Uttar Pradesh     Madurai     Kids      T-shirts
# 7890  Zudio   India    Maharashtra      Indore     Kids        Shirts
# 7891  Zudio   India     Tamil Nadu       Kochi      Men       Dresses
# 7892  Zudio   India  Uttar Pradesh    Vadodara    Women      Sweaters
# 7893  Zudio   India      Rajasthan   Hyderabad    Women       Jackets
# 7894  Zudio   India  Uttar Pradesh  Chandigarh     Kids         Jeans
# 7895  Zudio   India  Uttar Pradesh  Aurangabad     Kids       Jackets
# 7896  Zudio   India     Tamil Nadu        Pune     Kids      T-shirts
# 7897  Zudio   India          Delhi     Madurai      Men         Shoes
# 7898  Zudio   India        Gujarat   Bengaluru    Women        Shirts
#
#       Store Number  Postal Code Store Type Store Open Date  ...  \
# 7889            82       429075     Rented      2023-03-08  ...
# 7890            12       402636     Rented      2023-02-12  ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7899 entries, 0 to 7898
# Data columns (total 28 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Store                      7899 non-null   object
#  1   Country                    7899 non-null   object
#  2   State                      7899 non-null   object
#  3   City                       7899 non-null   object
#  4   Category                   7899 non-null   object
#  5   Clothing Type              7899 non-null   object
#  6   Store Number               7899 non-null   int64
#  7   Postal Code                7899 non-null   int64
#  8   Store Type                 7899 non-null   object
#  9   Store Open Date            7899 non-null   object
#  10  Selling Area Size (sq ft)  7899 non-null   int64
#  11  Store Manager              7899 non-null   object
#  12  Manager ID                 7899 non-null   object
# ...

# %%
df.shape
# Out:
# (7899, 28)

# %%
df.dtypes
# Out:
# Store                         object
# Country                       object
# State                         object
# City                          object
# Category                      object
# Clothing Type                 object
# Store Number                   int64
# Postal Code                    int64
# Store Type                    object
# Store Open Date               object
# Selling Area Size (sq ft)      int64
# Store Manager                 object
# Manager ID                    object
# Store Address                 object
# Contact Information           object
# Operating Hours               object
# Staff Count                    int64
# Parking Availability          object
# Security Features             object
# Order ID                       int64
# Order Date                    object
# Month                         object
# Customer ID                    int64
# Customer Name                 object
# Product ID                     int64
# ...

# %%
df.describe()
# Out:
#        Store Number    Postal Code  Selling Area Size (sq ft)  Staff Count  \
# count   7899.000000    7899.000000                7899.000000  7899.000000
# mean      50.666034  419982.374984                1112.077478    11.504747
# std       29.095274   11695.237817                 193.239371     5.194722
# min        1.000000  400006.000000                 800.000000     3.000000
# 25%       25.000000  409841.000000                 950.000000     7.000000
# 50%       51.000000  419988.000000                1100.000000    12.000000
# 75%       76.000000  430258.000000                1300.000000    16.000000
# max      100.000000  439985.000000                1400.000000    20.000000
#
#            Order ID    Customer ID   Product ID        Price     Quantity  \
# count   7899.000000    7899.000000  7899.000000  7899.000000  7899.000000
# mean   54920.719965  549440.714521   602.069376  1761.113432     4.519433
# ...

# %%
df['City']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'City'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_3631/427905057.py in <cell line: 0>()
# ----> 1 df['City']
#
# ...

# %%
import pandas as pd
df=pd.read_csv("/content/titanic uncleaned.csv")

# %%
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
# 5          897         0       3
# 6          898         1       3
# 7          899         0       2
# 8          900         1       3
# 9          901         0       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# 5                    Svensson, Mr. Johan Cervin    male  14.0      0      0
# ...

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   418.000000  418.000000  418.000000  332.000000  418.000000
# mean   1100.500000    0.363636    2.265550   30.272590    0.447368
# std     120.810458    0.481622    0.841838   14.181209    0.896760
# min     892.000000    0.000000    1.000000    0.170000    0.000000
# 25%     996.250000    0.000000    1.000000   21.000000    0.000000
# 50%    1100.500000    0.000000    3.000000   27.000000    0.000000
# 75%    1204.750000    1.000000    3.000000   39.000000    1.000000
# max    1309.000000    1.000000    3.000000   76.000000    8.000000
#
#             Parch        Fare
# count  418.000000  417.000000
# mean     0.392344   35.627188
# std      0.981429   55.907576
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   14.454200
# 75%      0.000000   31.500000
# max      9.000000  512.329200

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 39.3+ KB

# %%
df['Age_mean_imputed']=df['Age'].fillna( df['Age'].mean())
df['Age_median_imputed']=df['Age'].fillna( df['Age'].median())
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
df['Cabin_mode_imputed']=df['Cabin'].fillna(df['Cabin'].mode()[0])
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_17151/1015727612.py in <cell line: 0>()
#       1 import pandas as pd
# ----> 2 one_hot_encoded = pd.get_dummies(encoded_data['Embarked'], prefix='Embarked')
#       3 encoded_data = pd.concat([encoded_data, one_hot_encoded], axis=1)
#       4
#       5 # Since 'Pclass' is ordinal, we can create a mapped column for demonstration.
#
# NameError: name 'encoded_data' is not defined

# %%
df[['Age','Age_median_im
# Out:
#       Age  Age_median_imputed
# 0    34.5                34.5
# 1    47.0                47.0
# 2    62.0                62.0
# 3    27.0                27.0
# 4    22.0                22.0
# ..    ...                 ...
# 413   NaN                27.0
# 414  39.0                39.0
# 415  38.5                38.5
# 416   NaN                27.0
# 417   NaN                27.0
#
# [418 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="whitegrid")
plt.figure(figsize=(10,6))
sns.boxplot(data=df,x='Pclass',y='Survived',palette='pastel')
plt.title('Boxplot of Age by Passenger Class',fontsize=16)
# Out:
# /tmp/ipykernel_3631/530763105.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df,x='Pclass',y='Survived',palette='pastel')
# Text(0.5, 1.0, 'Boxplot of Age by Passenger Class')

# %%
plt.title('Boxplot of Age by Passenger Class',fontsize=16)
plt.xlabel('Passenger Class',fontsize=12)
plt.ylabel('Age',fontsize=12)
plt.show()

# %%
import pandas as pd
df=pd.read_csv("/content/titanic uncleaned.csv")
from sklearn.preprocessing import LabelEncoder
encoded_data=df.copy()
label_encoder=LabelEncoder()
df['Sex_encoded']=label_encoder.fit_transform(df['Sex'])
one_hot_encoded_data=pd.get_dummies(df,columns=['Embarked'])
encoded_data=pd.concat([encoded_data,one_hot_encoded_data],axis=1)
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...
