# %% [markdown]
# <a href="https://colab.research.google.com/github/johnjoseph004/AI-ML-internship/blob/main/practice_day2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv("/content/preprocessing_practice_dataset.csv")
df.isnull().sum()
# Out:
# Employee_ID            0
# Age                   10
# Gender                 0
# Department            10
# Education             10
# Experience_Years       0
# Monthly_Salary        10
# Performance_Rating     0
# City                  10
# Attrition              0
# dtype: int64

# %%
df['Age_mean_imputed']=df['Age'].fillna( df['Age'].mean())
df['Age_median_imputed']=df['Age'].fillna( df['Age'].median())
df['Salary_mean_imputed']=df['Monthly_Salary'].fillna( df['Monthly_Salary'].mean())
df['Salary_median_imputed']=df['Monthly_Salary'].fillna( df['Monthly_Salary'].median())

df
# Out:
#     Employee_ID   Age  ... Salary_mean_imputed Salary_median_imputed
# 0          1001  59.0  ...             52350.0               52350.0
# 1          1002  49.0  ...            118008.0              118008.0
# 2          1003  35.0  ...            119297.0              119297.0
# 3          1004  28.0  ...             50351.0               50351.0
# 4          1005  41.0  ...            113668.0              113668.0
# ..          ...   ...  ...                 ...                   ...
# 95         1096  54.0  ...             48625.0               48625.0
# 96         1097  53.0  ...            107873.0              107873.0
# 97         1098  43.0  ...             97592.0               97592.0
# 98         1099  44.0  ...            102052.0              102052.0
# 99         1100  57.0  ...             69261.0               69261.0
#
# [100 rows x 17 columns]

# %%
df['Education_mode_imputed']=df['Education'].fillna(df['Education'].mode()[0])
df['Department_mode_imputed']=df['Department'].fillna(df['Department'].mode()[0])
df['City_mode_imputed']=df['City'].fillna(df['City'].mode()[0])
df
# Out:
#     Employee_ID   Age  ... Department_mode_imputed City_mode_imputed
# 0          1001  59.0  ...                      HR           Calicut
# 1          1002  49.0  ...               Marketing           Chennai
# 2          1003  35.0  ...                      HR             Kochi
# 3          1004  28.0  ...                      HR        Trivandrum
# 4          1005  41.0  ...                      IT        Trivandrum
# ..          ...   ...  ...                     ...               ...
# 95         1096  54.0  ...                      HR           Chennai
# 96         1097  53.0  ...               Marketing        Trivandrum
# 97         1098  43.0  ...                      HR           Chennai
# 98         1099  44.0  ...               Marketing           Calicut
# 99         1100  57.0  ...                      HR           Calicut
#
# [100 rows x 15 columns]

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(10,6))
sns.boxplot(data=df,x='Experience_Years',y='Monthly_Salary',palette='pastel')
plt.title('Boxplot of Experience by Salary',fontsize=16)
# Out:
# /tmp/ipykernel_1271/770906494.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df,x='Experience_Years',y='Monthly_Salary',palette='pastel')
# Text(0.5, 1.0, 'Boxplot of Experience by Salary')

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(10,6))
sns.lineplot(data=df,x='Experience_Years',y='Monthly_Salary',palette='pastel')
plt.title('Boxplot of Experience by Salary',fontsize=16)
# Out:
# /tmp/ipykernel_1271/2914480705.py:3: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.lineplot(data=df,x='Experience_Years',y='Monthly_Salary',palette='pastel')
# Text(0.5, 1.0, 'Boxplot of Experience by Salary')

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(10,6))
sns.histplot(data=df,x='Experience_Years',y='Monthly_Salary',palette='pastel')
plt.title('Boxplot of Experience by Salary',fontsize=16)
# Out:
# /tmp/ipykernel_1271/3123696761.py:3: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(data=df,x='Experience_Years',y='Monthly_Salary',palette='pastel')
# Text(0.5, 1.0, 'Boxplot of Experience by Salary')

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(10,6))
sns.scatterplot(data=df,x='Experience_Years',y='Monthly_Salary',palette='pastel')
plt.title('Boxplot of Experience by Salary',fontsize=16)
# Out:
# /tmp/ipykernel_1271/2135211327.py:3: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(data=df,x='Experience_Years',y='Monthly_Salary',palette='pastel')
# Text(0.5, 1.0, 'Boxplot of Experience by Salary')

# %%
education_counts = df['Education_mode_imputed'].value_counts()

plt.figure(figsize=(8, 8))
plt.pie(education_counts, labels=education_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Distribution of Education (Mode Imputed)', fontsize=16)
plt.axis('equal') # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder=LabelEncoder()
encoded_df=df.copy()
df['Gender_encoded']=label_encoder.fit_transform(df['Gender'])
df['City_encoded']=label_encoder.fit_transform(df['City'])
df['Department_encoded']=label_encoder.fit_transform(df['Department'])
df['Education_encoded']=label_encoder.fit_transform(df['Education'])
# Out:
# 0        Calicut
# 1        Chennai
# 2          Kochi
# 3     Trivandrum
# 4     Trivandrum
#          ...
# 95       Chennai
# 96    Trivandrum
# 97       Chennai
# 98       Calicut
# 99       Calicut
# Name: City, Length: 100, dtype: object

# %%
encoded_df = pd.get_dummies(encoded_df, columns=['City'], prefix='City')
encoded_df
# Out:
#     Employee_ID   Age  Gender  ... City_Chennai City_Kochi  City_Trivandrum
# 0          1001  59.0    Male  ...        False      False            False
# 1          1002  49.0  Female  ...         True      False            False
# 2          1003  35.0  Female  ...        False       True            False
# 3          1004  28.0  Female  ...        False      False             True
# 4          1005  41.0    Male  ...        False      False             True
# ..          ...   ...     ...  ...          ...        ...              ...
# 95         1096  54.0  Female  ...         True      False            False
# 96         1097  53.0    Male  ...        False      False             True
# 97         1098  43.0    Male  ...         True      False            False
# 98         1099  44.0  Female  ...        False      False            False
# 99         1100  57.0  Female  ...        False      False            False
#
# [100 rows x 25 columns]

# %%
from sklearn.preprocessing import MinMaxScaler,StandardScaler
numerical_columns=['Age','Experience_Years','Monthly_Salary']
df.dropna(subset=numerical_columns,inplace=True)

minmax_scaler=MinMaxScaler()
standard_scaler=StandardScaler()
df['Age_MinMax']=minmax_scaler.fit_transform(df[['Age']])
df['Salary_MinMax']=minmax_scaler.fit_transform(df[['Monthly_Salary']])
df['Age_Standard']=standard_scaler.fit_transform(df[['Age']])
df['Salary_Standard']=standard_scaler.fit_transform(df[['Monthly_Salary']])
df
# Out:
#     Employee_ID   Age  Gender  ... Salary_MinMax Age_Standard  Salary_Standard
# 0          1001  59.0    Male  ...      0.286925     1.811984        -0.802101
# 1          1002  49.0  Female  ...      0.986270     0.889855         1.557801
# 2          1003  35.0  Female  ...      1.000000    -0.401126         1.604131
# 3          1004  28.0  Female  ...      0.265633    -1.046617        -0.873950
# 4          1005  41.0    Male  ...      0.940044     0.152151         1.401811
# ..          ...   ...     ...  ...           ...          ...              ...
# 95         1096  54.0  Female  ...      0.247249     1.350919        -0.935986
# 96         1097  53.0    Male  ...      0.878319     1.258706         1.193525
# 97         1098  43.0    Male  ...      0.768813     0.336577         0.824002
# 98         1099  44.0  Female  ...      0.816318     0.428790         0.984305
# 99         1100  57.0  Female  ...      0.467050     1.627558        -0.194280
#
# [80 rows x 25 columns]
